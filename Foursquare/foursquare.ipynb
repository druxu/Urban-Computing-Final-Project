# %%
# !pip install transformers tqdm scikit-learn  

import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from transformers import DistilBertTokenizer, DistilBertModel, AdamW
from tqdm import tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
checkins_file = "/kaggle/input/4square/dataset_TIST2015_Checkins.txt"
df_tist = pd.read_csv(
    checkins_file,
    sep="\s+",
    header=None,  # no header in the file
    names=[
        "user_id",
        "venue_id",
        "dow",
        "month",
        "day",
        "clock",
        "tz_sign",   # or "year" if your order differs
        "year",
        "offset_minutes",
    ],
)
print(df_tist.head(5))
# Out:
#    user_id                  venue_id  dow month  day     clock  tz_sign  \
# 0    50756  4f5e3a72e4b053fd6a4313f6  Tue   Apr  3.0  18:00:06      0.0
# 1   190571  4b4b87b5f964a5204a9f26e3  Tue   Apr  3.0  18:00:07      0.0
# 2   221021  4a85b1b3f964a520eefe1fe3  Tue   Apr  3.0  18:00:08      0.0
# 3    66981  4b4606f2f964a520751426e3  Tue   Apr  3.0  18:00:08      0.0
# 4    21010  4c2b4e8a9a559c74832f0de2  Tue   Apr  3.0  18:00:09      0.0
#
#      year  offset_minutes
# 0  2012.0           240.0
# 1  2012.0           180.0
# 2  2012.0          -240.0
# 3  2012.0          -300.0
# 4  2012.0           240.0

# %%
pois_file = "/kaggle/input/4square/dataset_TIST2015_POIs.txt"
df_pois = pd.read_csv(
    pois_file,
    sep="\t",
    header=None,
    names=["venue_id","latitude","longitude","category","country"]
)
print(df_pois.head(5))
# Out:
#                    venue_id   latitude  longitude           category country
# 0  3fd66200f964a52000e71ee3  40.733596 -74.003139          Jazz Club      US
# 1  3fd66200f964a52000e81ee3  40.758102 -73.975734                Gym      US
# 2  3fd66200f964a52000ea1ee3  40.732456 -74.003755  Indian Restaurant      US
# 3  3fd66200f964a52000ec1ee3  42.345907 -71.087001  Indian Restaurant      US
# 4  3fd66200f964a52000ee1ee3  39.933178 -75.159262     Sandwich Place      US

# %%
df_merged = pd.merge(df_tist, df_pois, on="venue_id", how="inner")
print(df_merged.head(5))
# Out:
#    user_id                  venue_id  dow month  day     clock  tz_sign  \
# 0    50756  4f5e3a72e4b053fd6a4313f6  Tue   Apr  3.0  18:00:06      0.0
# 1   190571  4b4b87b5f964a5204a9f26e3  Tue   Apr  3.0  18:00:07      0.0
# 2   212251  4b4b87b5f964a5204a9f26e3  Wed   Apr  4.0  05:49:28      0.0
# 3   227763  4b4b87b5f964a5204a9f26e3  Wed   Apr  4.0  12:10:31      0.0
# 4   212251  4b4b87b5f964a5204a9f26e3  Wed   Apr  4.0  12:53:32      0.0
#
#      year  offset_minutes   latitude  longitude              category country
# 0  2012.0           240.0  55.696132  37.557842           Comedy Club      RU
# 1  2012.0           180.0  41.029717  28.974420  Other Great Outdoors      TR
# 2  2012.0           180.0  41.029717  28.974420  Other Great Outdoors      TR
# 3  2012.0           180.0  41.029717  28.974420  Other Great Outdoors      TR
# 4  2012.0           180.0  41.029717  28.974420  Other Great Outdoors      TR

# %%
print(df_merged.head(10))

# %%
def parse_tist_datetime(row):
    """
    Convert columns (dow, month, day, clock, year, offset_minutes)
    into a single datetime string like:
       "Tue Apr 03 18:00:06 +0400 2012"
    and parse with format="%a %b %d %H:%M:%S %z %Y".
    """
    # 1. Convert offset_minutes -> +HHMM or -HHMM
    offset = row.get("offset_minutes", 0.0)
    if pd.isna(offset):
        offset = 0.0
    offset = int(offset)  # e.g. 240 -> +4 hours
    hours = abs(offset) // 60
    mins = abs(offset) % 60
    sign = "+" if offset >= 0 else "-"
    offset_str = f"{sign}{hours:02d}{mins:02d}"  # e.g. "+0400" or "-0530"

    # 2. Convert day (float) -> int -> string
    day_val = row.get("day", 1.0)
    if pd.isna(day_val):
        day_val = 1.0
    day_val = int(day_val)  # e.g. 3.0 -> 3

    # 3. Convert year (float) -> int -> string
    year_val = row.get("year", 2012.0)
    if pd.isna(year_val):
        year_val = 2012.0
    year_val = int(year_val)  # e.g. 2012.0 -> 2012

    # 4. Build the final string
    #    Example: "Tue Apr 3 18:00:06 +0400 2012"
    dow_str = str(row.get("dow", "Mon"))        # "Tue"
    mon_str = str(row.get("month", "Jan"))      # "Apr"
    clk_str = str(row.get("clock", "00:00:00")) # "18:00:06"

    raw_str = f"{dow_str} {mon_str} {day_val} {clk_str} {offset_str} {year_val}"

    # 5. Parse using the matching format
    dt = pd.to_datetime(raw_str, format="%a %b %d %H:%M:%S %z %Y", errors="coerce")
    return dt

# %%
print(df_merged.columns)

# %%
def make_lat_lon_buckets(df, lat_multiplier=10, lon_multiplier=10):
    # 1. Convert lat/lon to numeric
    df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
    df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")

    # 2. Drop rows with missing or inf lat/lon
    df = df.dropna(subset=["latitude", "longitude"])
    df = df[~df["latitude"].isin([np.inf, -np.inf])]
    df = df[~df["longitude"].isin([np.inf, -np.inf])]

    # 3. Create lat/lon buckets
    df["lat_bucket"] = (df["latitude"] * lat_multiplier).astype(int)
    df["lon_bucket"] = (df["longitude"] * lon_multiplier).astype(int)
    return df

df_merged = make_lat_lon_buckets(df_merged)

# %%
df_merged['check_in_time'] = pd.to_datetime(df_merged['check_in_time'], utc=True)

# %%
df_merged['hour_of_day'] = df_merged['check_in_time'].dt.hour
df_merged['check_in_time'] = df_merged['check_in_time'].dt.tz_convert('America/New_York')
df_merged['hour_of_day'] = df_merged['check_in_time'].dt.hour

# %%
def fix_and_parse_datetime(df):
    df["check_in_time"] = df.apply(parse_tist_datetime, axis=1)
    df = df.dropna(subset=["check_in_time"]).copy()
    return df

df_merged = fix_and_parse_datetime(df_merged)
print(df_merged[["check_in_time", "dow", "month", "day", "clock", "offset_minutes"]].head(20))

# %%
def make_lat_lon_buckets(df, lat_multiplier=10, lon_multiplier=10):
    # 1. Convert lat/lon to numeric
    df["latitude"] = pd.to_numeric(df["latitude"], errors="coerce")
    df["longitude"] = pd.to_numeric(df["longitude"], errors="coerce")

    # 2. Drop rows with missing or inf lat/lon
    df = df.dropna(subset=["latitude", "longitude"])
    df = df[~df["latitude"].isin([np.inf, -np.inf])]
    df = df[~df["longitude"].isin([np.inf, -np.inf])]

    # 3. Create lat/lon buckets
    df["lat_bucket"] = (df["latitude"] * lat_multiplier).astype(int)
    df["lon_bucket"] = (df["longitude"] * lon_multiplier).astype(int)
    return df

df_merged = make_lat_lon_buckets(df_merged)

# %%
def construct_trajectories(data, time_window="1D"):
    trajectories = []
    grouped = data.groupby("user_id", group_keys=False)
    for user_id, group in grouped:
        group = group.sort_values("check_in_time").copy()
        group["trajectory_id"] = (group["check_in_time"].diff() > pd.Timedelta(time_window)).cumsum()

        for traj_id, traj_group in group.groupby("trajectory_id"):
            trajectory = {
                "user_id": user_id,
                "trajectory_id": traj_id,
                "timestamps": traj_group["check_in_time"].tolist(),
                "locations": traj_group["venue_id"].tolist(),
                "day_of_week": traj_group["day_of_week"].tolist(),
                "hour_of_day": traj_group["hour_of_day"].tolist(),
                "lat_bucket": traj_group["lat_bucket"].tolist(),
                "lon_bucket": traj_group["lon_bucket"].tolist()
            }
            trajectories.append(trajectory)

    return pd.DataFrame(trajectories)

trajectories_df = construct_trajectories(df_merged, time_window="1D")
print(trajectories_df.head(5))

# %%
def encode_pois(trajectories_df):
    all_locations = set(loc for traj in trajectories_df["locations"] for loc in traj)
    location_mapping = {loc: idx for idx, loc in enumerate(all_locations)}

    trajectories_df["encoded_locations"] = trajectories_df["locations"].apply(
        lambda locs: [location_mapping[loc] for loc in locs]
    )
    return trajectories_df, location_mapping

trajectories_df, poi_mapping = encode_pois(trajectories_df)
trajectories_df.head()

# %%
# loaded saved preprocessed trajectories
trajectories_df = pd.read_csv("/kaggle/input/4sq-traject/foursquare_trajectories.csv")

# %%
print(trajectories_df.head())
# Out:
#    user_id  trajectory_id                                         timestamps  \
# 0        1              0  [Timestamp('2012-04-03 18:19:17-0400', tz='Ame...
# 1        1              1  [Timestamp('2012-04-06 15:09:58-0400', tz='Ame...
# 2        1              2  [Timestamp('2012-04-12 09:33:06-0400', tz='Ame...
# 3        1              3  [Timestamp('2012-04-13 09:35:55-0400', tz='Ame...
# 4        1              4  [Timestamp('2012-04-16 13:24:29-0400', tz='Ame...
#
#                                            locations  \
# 0  ['4e753db3c65bb91db4493d78', '4f691503e4b072f1...
# 1  ['4beed97de24d20a1f2777314', '4b5c5402f964a520...
# 2  ['4e753db3c65bb91db4493d78', '4c597bc36407d13a...
# 3  ['4e753db3c65bb91db4493d78', '4bd3283041b9ef3b...
# 4  ['4c15395a77cea593a6dcd160', '4bf20f1025afb713...
#
#                                          day_of_week  \
# 0                       ['Tue', 'Tue', 'Tue', 'Wed']
# 1  ['Fri', 'Fri', 'Fri', 'Sat', 'Sat', 'Sat', 'Sa...
# 2                              ['Thu', 'Thu', 'Thu']
# 3  ['Fri', 'Sat', 'Sat', 'Sat', 'Sat', 'Sat', 'Sa...
# 4                              ['Mon', 'Mon', 'Mon']
#
#                                          hour_of_day  \
# 0                                    [18, 18, 18, 0]
# 1  [15, 15, 15, 12, 12, 12, 12, 12, 12, 12, 13, 1...
# 2                                          [9, 9, 9]
# 3  [9, 0, 0, 0, 12, 12, 22, 22, 22, 22, 22, 22, 2...
# 4                                       [13, 13, 16]
#
#                                           lat_bucket  \
# 0                               [406, 406, 406, 406]
# 1  [407, 407, 407, 406, 406, 406, 406, 406, 406, ...
# 2                                    [406, 406, 406]
# 3  [406, 406, 406, 406, 407, 407, 406, 406, 406, ...
# 4                                    [407, 407, 406]
#
#                                           lon_bucket  \
# 0                           [-736, -736, -736, -736]
# 1  [-736, -736, -736, -736, -736, -736, -736, -73...
# 2                                 [-736, -736, -736]
# 3  [-736, -736, -736, -736, -736, -736, -736, -73...
# 4                                 [-736, -736, -736]
#
#                                    encoded_locations
# 0                [1021356, 435011, 2760516, 1021356]
# 1  [1543848, 1109871, 964344, 3550116, 1851247, 1...
# 2                         [1021356, 200445, 3219063]
# 3  [1021356, 1545838, 2994984, 3194534, 2451602, ...
# 4                         [463771, 2474926, 1021356]

# %%
unique_users = trajectories_df["user_id"].unique()
random.seed(42)
selected_users = random.sample(list(unique_users), 270)

filtered_df = trajectories_df[trajectories_df["user_id"].isin(selected_users)].reset_index(drop=True)

label_encoder = LabelEncoder()
filtered_df["label"] = label_encoder.fit_transform(filtered_df["user_id"])
num_users = len(label_encoder.classes_)
print(f"Selected {num_users} users.")
# Out:
# Selected 270 users.

# %%
train_df, val_df = train_test_split(filtered_df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
def build_mixed_trajectory(loc_ids, days, hours, lat_buckets, lon_buckets):
    tokens = []
    for loc_id, d, h, latb, lonb in zip(loc_ids, days, hours, lat_buckets, lon_buckets):
        token = f"POI{loc_id}_DAY{d}_H{h}_LAT{latb}_LON{lonb}"
        tokens.append(token)
    return " ".join(tokens)

class SpatioTemporalFoursquareDataset(Dataset):
    def __init__(self, df, tokenizer, max_length=128):
        self.df = df
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.labels = df["label"].values  # integer user IDs

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        loc_ids = row["encoded_locations"]
        days = row["day_of_week"]
        hours = row["hour_of_day"]
        latb = row["lat_bucket"]
        lonb = row["lon_bucket"]

        # Build spatio-temporal token string
        trajectory_str = build_mixed_trajectory(loc_ids, days, hours, latb, lonb)

        # Tokenize
        inputs = self.tokenizer(
            trajectory_str,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors="pt",
        )

        label = self.labels[idx]

        return {
            'input_ids': inputs['input_ids'].squeeze(0),
            'attention_mask': inputs['attention_mask'].squeeze(0),
            'label': torch.tensor(label, dtype=torch.long)
        }

# Instantiate tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# Create datasets
train_dataset = SpatioTemporalFoursquareDataset(train_df, tokenizer, max_length=128)
val_dataset = SpatioTemporalFoursquareDataset(val_df, tokenizer, max_length=128)

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
class TrajectoryDistilBERT(nn.Module):
    def __init__(self, num_users, dropout_rate=0.1):
        super(TrajectoryDistilBERT, self).__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.bert.config.dim, num_users)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]  # DistilBERT's "CLS" token
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# %%
def compute_metrics(outputs, labels, top_ks=[1, 5]):
    metrics = {}
    with torch.no_grad():
        for k in top_ks:
            _, topk_indices = torch.topk(outputs, k=k, dim=1)
            correct_topk = sum(labels[i].item() in topk_indices[i] for i in range(labels.size(0)))
            metrics[f"ACC@{k}"] = correct_topk / labels.size(0)

    _, preds = torch.max(outputs, dim=1)
    metrics["top1_preds"] = preds
    return metrics

from sklearn.metrics import classification_report

def evaluate_model(model, loader, device, loss_fn):
    model.eval()
    total_loss = 0.0
    all_preds, all_labels = [], []
    acc_metrics = {"ACC@1": 0, "ACC@5": 0}
    total_samples = 0

    with torch.no_grad():
        for batch in loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            batch_size = labels.size(0)
            total_loss += loss.item() * batch_size

            batch_metrics = compute_metrics(outputs, labels)
            acc_metrics["ACC@1"] += batch_metrics["ACC@1"] * batch_size
            acc_metrics["ACC@5"] += batch_metrics["ACC@5"] * batch_size

            all_preds.extend(batch_metrics["top1_preds"].cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_samples += batch_size

    avg_loss = total_loss / total_samples
    acc_metrics["ACC@1"] /= total_samples
    acc_metrics["ACC@5"] /= total_samples

    cls_metrics = classification_report(all_labels, all_preds, output_dict=True)
    return avg_loss, acc_metrics, cls_metrics

# %%
def train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=5):
    for epoch in range(epochs):
        model.train()
        total_loss = 0.0
        train_iter = tqdm(train_loader, desc=f"Epoch {epoch+1} [Training]", leave=False)

        for batch in train_iter:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            train_iter.set_description(f"Epoch {epoch+1} [Training] loss: {loss.item():.4f}")

        # Evaluate after each epoch
        train_loss, train_acc_metrics, _ = evaluate_model(model, train_loader, device, loss_fn)
        val_loss, val_acc_metrics, val_cls_report = evaluate_model(model, val_loader, device, loss_fn)

        print(f"\nEpoch {epoch+1}:")
        print(f"  Train Loss: {train_loss:.4f} | ACC@1: {train_acc_metrics['ACC@1']:.4f}, ACC@5: {train_acc_metrics['ACC@5']:.4f}")
        print(f"  Val   Loss: {val_loss:.4f}   | ACC@1: {val_acc_metrics['ACC@1']:.4f}, ACC@5: {val_acc_metrics['ACC@5']:.4f}")
        print(f"  Val Macro F1: {val_cls_report['macro avg']['f1-score']:.4f}, Weighted F1: {val_cls_report['weighted avg']['f1-score']:.4f}")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TrajectoryDistilBERT(num_users, dropout_rate=0.0) 
model.to(device)

optimizer = AdamW(model.parameters(), lr=2e-5)
loss_fn = nn.CrossEntropyLoss()

epochs = 1
train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=epochs)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1:
#   Train Loss: 3.3036 | ACC@1: 0.3003, ACC@5: 0.6179
#   Val   Loss: 3.3560   | ACC@1: 0.2862, ACC@5: 0.6142
#   Val Macro F1: 0.1179, Weighted F1: 0.1788
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Using best parameters for 270 users

# %%
# Random subset of users
unique_users = trajectories_df['user_id'].unique()
random.seed(42)
selected_users = random.sample(list(unique_users), 270)

filtered_df = trajectories_df[trajectories_df['user_id'].isin(selected_users)].reset_index(drop=True)

# Label encode user_id
label_encoder = LabelEncoder()
filtered_df["label"] = label_encoder.fit_transform(filtered_df["user_id"])
num_users = len(label_encoder.classes_)
print(f"Number of selected users: {num_users}")

train_df, val_df = train_test_split(filtered_df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
# Out:
# Number of selected users: 270

# %%
# Best Hyperparams
best_dropout = 0.0
best_lr = 3e-5
best_batch_size = 16
best_max_length = 128

train_dataset = SpatioTemporalFoursquareDataset(train_df, tokenizer, max_length=best_max_length)
val_dataset = SpatioTemporalFoursquareDataset(val_df, tokenizer, max_length=best_max_length)

train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)

# %%
class TrajectoryDistilBERT(nn.Module):
    def __init__(self, num_users, dropout_rate=0.1):
        super(TrajectoryDistilBERT, self).__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.bert.config.dim, num_users)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        # DistilBERT's last_hidden_state: (batch_size, seq_len, hidden_size)
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# %%
# Build the model 
model = TrajectoryDistilBERT(num_users, dropout_rate=best_dropout)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# TrajectoryDistilBERT(
#   (bert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (classifier): Linear(in_features=768, out_features=270, bias=True)
# )

# %%
optimizer = AdamW(model.parameters(), lr=best_lr)
loss_fn = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
epochs = 10  
train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1:
#   Train Loss: 2.5334 | ACC@1: 0.4063, ACC@5: 0.7471
#   Val   Loss: 2.6008   | ACC@1: 0.3930, ACC@5: 0.7294
#   Val Macro F1: 0.2186, Weighted F1: 0.3016
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 2:
#   Train Loss: 1.8269 | ACC@1: 0.4818, ACC@5: 0.8410
#   Val   Loss: 1.9086   | ACC@1: 0.4709, ACC@5: 0.8230
#   Val Macro F1: 0.2979, Weighted F1: 0.3828
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 3:
#   Train Loss: 1.5708 | ACC@1: 0.5192, ACC@5: 0.8736
#   Val   Loss: 1.6760   | ACC@1: 0.5098, ACC@5: 0.8555
#   Val Macro F1: 0.3479, Weighted F1: 0.4402
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 4:
#   Train Loss: 1.4513 | ACC@1: 0.5238, ACC@5: 0.8850
#   Val   Loss: 1.5904   | ACC@1: 0.4874, ACC@5: 0.8623
#   Val Macro F1: 0.3482, Weighted F1: 0.4167
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 5:
#   Train Loss: 1.3680 | ACC@1: 0.5483, ACC@5: 0.8956
#   Val   Loss: 1.5271   | ACC@1: 0.5283, ACC@5: 0.8683
#   Val Macro F1: 0.3987, Weighted F1: 0.4699
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 6:
#   Train Loss: 1.3068 | ACC@1: 0.5575, ACC@5: 0.9058
#   Val   Loss: 1.5058   | ACC@1: 0.5231, ACC@5: 0.8719
#   Val Macro F1: 0.3981, Weighted F1: 0.4683
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 7:
#   Train Loss: 1.2235 | ACC@1: 0.5920, ACC@5: 0.9131
#   Val   Loss: 1.4484   | ACC@1: 0.5452, ACC@5: 0.8764
#   Val Macro F1: 0.4206, Weighted F1: 0.5041
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 8:
#   Train Loss: 1.1527 | ACC@1: 0.6121, ACC@5: 0.9210
#   Val   Loss: 1.4065   | ACC@1: 0.5656, ACC@5: 0.8816
#   Val Macro F1: 0.4443, Weighted F1: 0.5237
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 9:
#   Train Loss: 1.0636 | ACC@1: 0.6462, ACC@5: 0.9327
#   Val   Loss: 1.3736   | ACC@1: 0.5733, ACC@5: 0.8892
#   Val Macro F1: 0.4621, Weighted F1: 0.5415
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 10:
#   Train Loss: 0.9924 | ACC@1: 0.6692, ACC@5: 0.9403
#   Val   Loss: 1.3331   | ACC@1: 0.5953, ACC@5: 0.8912
#   Val Macro F1: 0.4847, Weighted F1: 0.5683
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # WITH TEST SET

# %%
# Random subset of users
unique_users = trajectories_df['user_id'].unique()
random.seed(42)
selected_users = random.sample(list(unique_users), 270)

filtered_df = trajectories_df[trajectories_df['user_id'].isin(selected_users)].reset_index(drop=True)

# Label encode user_id
label_encoder = LabelEncoder()
filtered_df["label"] = label_encoder.fit_transform(filtered_df["user_id"])
num_users = len(label_encoder.classes_)
print(f"Number of selected users: {num_users}")

# Split data into training, validation, and test sets
train_df, temp_df = train_test_split(filtered_df, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# Best Hyperparams
best_dropout = 0.0
best_lr = 3e-5
best_batch_size = 16
best_max_length = 128

# Create datasets
train_dataset = SpatioTemporalFoursquareDataset(train_df, tokenizer, max_length=best_max_length)
val_dataset = SpatioTemporalFoursquareDataset(val_df, tokenizer, max_length=best_max_length)
test_dataset = SpatioTemporalFoursquareDataset(test_df, tokenizer, max_length=best_max_length)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False)

# Define model
class TrajectoryDistilBERT(nn.Module):
    def __init__(self, num_users, dropout_rate=0.1):
        super(TrajectoryDistilBERT, self).__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.bert.config.dim, num_users)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# Build the model 
model = TrajectoryDistilBERT(num_users, dropout_rate=best_dropout)
model.to(device)

# Optimizer and loss
optimizer = AdamW(model.parameters(), lr=best_lr)
loss_fn = nn.CrossEntropyLoss()

# Training function
epochs = 10
train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=epochs)

# Evaluation function for test set


def evaluate_test_set(model, loader, device, loss_fn):
    model.eval()
    total_loss = 0.0
    all_preds, all_labels = [], []
    acc_metrics = {"ACC@1": 0, "ACC@5": 0}
    total_samples = 0

    with torch.no_grad():
        for batch in loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            batch_size = labels.size(0)
            total_loss += loss.item() * batch_size

            batch_metrics = compute_metrics(outputs, labels)
            acc_metrics["ACC@1"] += batch_metrics["ACC@1"] * batch_size
            acc_metrics["ACC@5"] += batch_metrics["ACC@5"] * batch_size

            all_preds.extend(batch_metrics["top1_preds"].cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_samples += batch_size

    # Compute averages
    avg_loss = total_loss / total_samples
    acc_metrics["ACC@1"] /= total_samples
    acc_metrics["ACC@5"] /= total_samples

    # Generate classification report
    cls_metrics = classification_report(all_labels, all_preds, output_dict=True)
    
    print(f"Test Loss: {avg_loss:.4f}")
    print(f"ACC@1: {acc_metrics['ACC@1']:.4f}")
    print(f"ACC@5: {acc_metrics['ACC@5']:.4f}")
    
    return avg_loss, acc_metrics, cls_metrics

# Evaluate the test set
print("Evaluating the model on the test set...")
evaluate_test_set(model, test_loader, device, loss_fn)
# Out:
# Number of selected users: 270
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1:
#   Train Loss: 4.1308 | ACC@1: 0.1410, ACC@5: 0.3740
#   Val   Loss: 4.1340   | ACC@1: 0.1472, ACC@5: 0.3967
#   Val Macro F1: 0.0289, Weighted F1: 0.0612
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 2:
#   Train Loss: 2.1017 | ACC@1: 0.4354, ACC@5: 0.8209
#   Val   Loss: 2.1747   | ACC@1: 0.4234, ACC@5: 0.8073
#   Val Macro F1: 0.2616, Weighted F1: 0.3269
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 3:
#   Train Loss: 1.7196 | ACC@1: 0.4858, ACC@5: 0.8504
#   Val   Loss: 1.8105   | ACC@1: 0.4572, ACC@5: 0.8308
#   Val Macro F1: 0.3197, Weighted F1: 0.3816
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 4:
#   Train Loss: 1.5597 | ACC@1: 0.5096, ACC@5: 0.8795
#   Val   Loss: 1.6864   | ACC@1: 0.4813, ACC@5: 0.8587
#   Val Macro F1: 0.3445, Weighted F1: 0.4084
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 5:
#   Train Loss: 1.4521 | ACC@1: 0.5216, ACC@5: 0.8840
#   Val   Loss: 1.6111   | ACC@1: 0.4979, ACC@5: 0.8651
#   Val Macro F1: 0.3685, Weighted F1: 0.4339
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 6:
#   Train Loss: 1.3797 | ACC@1: 0.5414, ACC@5: 0.8969
#   Val   Loss: 1.5672   | ACC@1: 0.5080, ACC@5: 0.8640
#   Val Macro F1: 0.3802, Weighted F1: 0.4536
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 7:
#   Train Loss: 1.3280 | ACC@1: 0.5505, ACC@5: 0.9051
#   Val   Loss: 1.5256   | ACC@1: 0.5241, ACC@5: 0.8769
#   Val Macro F1: 0.4026, Weighted F1: 0.4735
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 8:
#   Train Loss: 1.2620 | ACC@1: 0.5743, ACC@5: 0.9104
#   Val   Loss: 1.5020   | ACC@1: 0.5332, ACC@5: 0.8710
#   Val Macro F1: 0.4129, Weighted F1: 0.4873
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 9:
#   Train Loss: 1.1954 | ACC@1: 0.5980, ACC@5: 0.9172
#   Val   Loss: 1.4715   | ACC@1: 0.5600, ACC@5: 0.8731
#   Val Macro F1: 0.4478, Weighted F1: 0.5242
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 10:
#   Train Loss: 1.1392 | ACC@1: 0.6226, ACC@5: 0.9209
#   Val   Loss: 1.4331   | ACC@1: 0.5685, ACC@5: 0.8817
#   Val Macro F1: 0.4585, Weighted F1: 0.5273
# Evaluating the model on the test set...
# Test Loss: 1.3774
# ACC@1: 0.5675
# ACC@5: 0.8737
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (1.377356262993251,
#  {'ACC@1': 0.5674518201284796, 'ACC@5': 0.8736616702355461},
#  {'0': {'precision': 1.0,
#    'recall': 0.4666666666666667,
#    'f1-score': 0.6363636363636364,
#    'support': 15},
#   '1': {'precision': 1.0,
#    'recall': 0.8888888888888888,
#    'f1-score': 0.9411764705882353,
#    'support': 18},
#   '2': {'precision': 0.75,
#    'recall': 1.0,
#    'f1-score': 0.8571428571428571,
#    'support': 3},
#   '3': {'precision': 0.16666666666666666,
#    'recall': 0.4,
#    'f1-score': 0.23529411764705882,
#    'support': 5},
#   '4': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#   '5': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '6': {'precision': 0.8571428571428571,
#    'recall': 1.0,
#    'f1-score': 0.923076923076923,
#    'support': 6},
#   '7': {'precision': 0.6666666666666666,
#    'recall': 0.2857142857142857,
#    'f1-score': 0.4,
#    'support': 7},
#   '8': {'precision': 0.5454545454545454,
#    'recall': 0.8181818181818182,
#    'f1-score': 0.6545454545454545,
#    'support': 22},
#   '9': {'precision': 0.5555555555555556,
#    'recall': 0.7142857142857143,
#    'f1-score': 0.6250000000000001,
#    'support': 14},
#   '10': {'precision': 0.23809523809523808,
#    'recall': 0.25,
#    'f1-score': 0.24390243902439024,
#    'support': 20},
#   '11': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#   '13': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#   '14': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13},
#   '15': {'precision': 0.8333333333333334,
#    'recall': 0.5,
#    'f1-score': 0.625,
#    'support': 10},
#   '16': {'precision': 0.8,
#    'recall': 1.0,
#    'f1-score': 0.888888888888889,
#    'support': 16},
#   '17': {'precision': 0.5,
#    'recall': 0.6111111111111112,
#    'f1-score': 0.55,
#    'support': 18},
#   '18': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 19},
#   '20': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '21': {'precision': 0.71875,
#    'recall': 1.0,
#    'f1-score': 0.8363636363636363,
#    'support': 23},
#   '22': {'precision': 0.5,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.5714285714285715,
#    'support': 6},
#   '23': {'precision': 0.75,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.5454545454545454,
#    'support': 7},
#   '24': {'precision': 0.7368421052631579,
#    'recall': 0.875,
#    'f1-score': 0.7999999999999999,
#    'support': 16},
#   '25': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#   '26': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 2},
#   '27': {'precision': 1.0,
#    'recall': 0.9444444444444444,
#    'f1-score': 0.9714285714285714,
#    'support': 18},
#   '28': {'precision': 0.45454545454545453,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.3846153846153846,
#    'support': 15},
#   '29': {'precision': 1.0,
#    'recall': 0.5,
#    'f1-score': 0.6666666666666666,
#    'support': 2},
#   '30': {'precision': 1.0,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.5,
#    'support': 3},
#   '31': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7},
#   '32': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '33': {'precision': 0.22727272727272727,
#    'recall': 1.0,
#    'f1-score': 0.37037037037037035,
#    'support': 10},
#   '34': {'precision': 0.8095238095238095,
#    'recall': 1.0,
#    'f1-score': 0.8947368421052632,
#    'support': 17},
#   '35': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 14},
#   '36': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 9},
#   '37': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#   '38': {'precision': 0.96, 'recall': 0.96, 'f1-score': 0.96, 'support': 25},
#   '39': {'precision': 0.5,
#    'recall': 1.0,
#    'f1-score': 0.6666666666666666,
#    'support': 1},
#   '40': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '41': {'precision': 0.7692307692307693,
#    'recall': 0.7142857142857143,
#    'f1-score': 0.7407407407407408,
#    'support': 14},
#   '42': {'precision': 0.28125,
#    'recall': 1.0,
#    'f1-score': 0.43902439024390244,
#    'support': 9},
#   '43': {'precision': 0.4444444444444444,
#    'recall': 0.8,
#    'f1-score': 0.5714285714285714,
#    'support': 5},
#   '44': {'precision': 1.0,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.6,
#    'support': 14},
#   '45': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 14},
#   '46': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 12},
#   '47': {'precision': 0.29411764705882354,
#    'recall': 1.0,
#    'f1-score': 0.45454545454545453,
#    'support': 5},
#   '48': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12},
#   '49': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '50': {'precision': 0.3111111111111111,
#    'recall': 0.7777777777777778,
#    'f1-score': 0.44444444444444436,
#    'support': 18},
#   '51': {'precision': 0.5714285714285714,
#    'recall': 0.4444444444444444,
#    'f1-score': 0.5,
#    'support': 9},
#   '52': {'precision': 1.0,
#    'recall': 0.75,
#    'f1-score': 0.8571428571428571,
#    'support': 4},
#   '53': {'precision': 0.5,
#    'recall': 0.7647058823529411,
#    'f1-score': 0.6046511627906976,
#    'support': 17},
#   '54': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '55': {'precision': 0.18604651162790697,
#    'recall': 0.5714285714285714,
#    'f1-score': 0.2807017543859649,
#    'support': 14},
#   '56': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#   '57': {'precision': 0.6666666666666666,
#    'recall': 1.0,
#    'f1-score': 0.8,
#    'support': 12},
#   '58': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 9},
#   '59': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7},
#   '60': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 19},
#   '61': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 17},
#   '62': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '63': {'precision': 1.0,
#    'recall': 0.8181818181818182,
#    'f1-score': 0.9,
#    'support': 11},
#   '64': {'precision': 0.5,
#    'recall': 0.3684210526315789,
#    'f1-score': 0.4242424242424242,
#    'support': 19},
#   '65': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 19},
#   '66': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '67': {'precision': 0.8,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.7272727272727272,
#    'support': 6},
#   '68': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#   '69': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '70': {'precision': 0.8888888888888888,
#    'recall': 1.0,
#    'f1-score': 0.9411764705882353,
#    'support': 8},
#   '71': {'precision': 0.9, 'recall': 0.9, 'f1-score': 0.9, 'support': 10},
#   '72': {'precision': 0.8,
#    'recall': 0.6153846153846154,
#    'f1-score': 0.6956521739130435,
#    'support': 13},
#   '73': {'precision': 0.8333333333333334,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.8333333333333334,
#    'support': 6},
#   '74': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#   '75': {'precision': 0.7692307692307693,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.7142857142857142,
#    'support': 15},
#   '76': {'precision': 0.9230769230769231,
#    'recall': 0.9230769230769231,
#    'f1-score': 0.9230769230769231,
#    'support': 13},
#   '78': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '79': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#   '81': {'precision': 1.0,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.5,
#    'support': 6},
#   '82': {'precision': 1.0,
#    'recall': 0.45454545454545453,
#    'f1-score': 0.625,
#    'support': 11},
#   '83': {'precision': 0.75, 'recall': 0.5, 'f1-score': 0.6, 'support': 6},
#   '84': {'precision': 0.75, 'recall': 0.5, 'f1-score': 0.6, 'support': 18},
#   '85': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '86': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 16},
#   '88': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '89': {'precision': 1.0,
#    'recall': 0.5,
#    'f1-score': 0.6666666666666666,
#    'support': 8},
#   '90': {'precision': 0.2,
#    'recall': 0.5,
#    'f1-score': 0.28571428571428575,
#    'support': 8},
#   '91': {'precision': 0.5,
#    'recall': 0.875,
#    'f1-score': 0.6363636363636364,
#    'support': 16},
#   '92': {'precision': 1.0,
#    'recall': 0.9090909090909091,
#    'f1-score': 0.9523809523809523,
#    'support': 11},
#   '93': {'precision': 0.8333333333333334,
#    'recall': 1.0,
#    'f1-score': 0.9090909090909091,
#    'support': 5},
#   '94': {'precision': 0.25,
#    'recall': 0.8,
#    'f1-score': 0.38095238095238093,
#    'support': 5},
#   '95': {'precision': 0.7916666666666666,
#    'recall': 0.9047619047619048,
#    'f1-score': 0.8444444444444444,
#    'support': 21},
#   '96': {'precision': 0.375,
#    'recall': 0.5294117647058824,
#    'f1-score': 0.4390243902439025,
#    'support': 17},
#   '97': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '98': {'precision': 0.4,
#    'recall': 0.4,
#    'f1-score': 0.4000000000000001,
#    'support': 10},
#   '99': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 16},
#   '100': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '101': {'precision': 0.9285714285714286,
#    'recall': 1.0,
#    'f1-score': 0.962962962962963,
#    'support': 13},
#   '102': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '103': {'precision': 0.75,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.7058823529411765,
#    'support': 9},
#   '105': {'precision': 1.0,
#    'recall': 0.8888888888888888,
#    'f1-score': 0.9411764705882353,
#    'support': 9},
#   '106': {'precision': 1.0,
#    'recall': 0.5,
#    'f1-score': 0.6666666666666666,
#    'support': 2},
#   '107': {'precision': 1.0,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.6,
#    'support': 14},
#   '108': {'precision': 0.9,
#    'recall': 0.8181818181818182,
#    'f1-score': 0.8571428571428572,
#    'support': 11},
#   '110': {'precision': 0.375,
#    'recall': 0.5,
#    'f1-score': 0.42857142857142855,
#    'support': 6},
#   '111': {'precision': 0.23255813953488372,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.3636363636363636,
#    'support': 12},
#   '112': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 4},
#   '113': {'precision': 1.0,
#    'recall': 0.75,
#    'f1-score': 0.8571428571428571,
#    'support': 4},
#   '114': {'precision': 1.0,
#    'recall': 0.8571428571428571,
#    'f1-score': 0.923076923076923,
#    'support': 7},
#   '115': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '116': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 13},
#   '117': {'precision': 0.4444444444444444,
#    'recall': 0.4,
#    'f1-score': 0.4210526315789474,
#    'support': 10},
#   '118': {'precision': 0.2857142857142857,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.30769230769230765,
#    'support': 6},
#   '119': {'precision': 0.4482758620689655,
#    'recall': 1.0,
#    'f1-score': 0.6190476190476191,
#    'support': 13},
#   '120': {'precision': 0.8,
#    'recall': 0.8,
#    'f1-score': 0.8000000000000002,
#    'support': 10},
#   '121': {'precision': 0.21212121212121213,
#    'recall': 0.7777777777777778,
#    'f1-score': 0.3333333333333333,
#    'support': 9},
#   '122': {'precision': 1.0,
#    'recall': 0.9090909090909091,
#    'f1-score': 0.9523809523809523,
#    'support': 11},
#   '123': {'precision': 0.21428571428571427,
#    'recall': 0.21428571428571427,
#    'f1-score': 0.21428571428571427,
#    'support': 14},
#   '124': {'precision': 0.4,
#    'recall': 0.15384615384615385,
#    'f1-score': 0.2222222222222222,
#    'support': 13},
#   '125': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '126': {'precision': 0.5,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.5714285714285715,
#    'support': 3},
#   '127': {'precision': 1.0,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.8,
#    'support': 3},
#   '128': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4},
#   '130': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '131': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '132': {'precision': 0.65,
#    'recall': 1.0,
#    'f1-score': 0.787878787878788,
#    'support': 13},
#   '134': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '135': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '136': {'precision': 0.6666666666666666,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.6666666666666666,
#    'support': 9},
#   '137': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13},
#   '138': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '139': {'precision': 0.8,
#    'recall': 0.8,
#    'f1-score': 0.8000000000000002,
#    'support': 5},
#   '140': {'precision': 0.5,
#    'recall': 0.625,
#    'f1-score': 0.5555555555555556,
#    'support': 8},
#   '141': {'precision': 0.09302325581395349,
#    'recall': 0.5714285714285714,
#    'f1-score': 0.16,
#    'support': 7},
#   '142': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 10},
#   '143': {'precision': 0.2,
#    'recall': 0.1,
#    'f1-score': 0.13333333333333333,
#    'support': 10},
#   '144': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '145': {'precision': 0.6,
#    'recall': 0.75,
#    'f1-score': 0.6666666666666665,
#    'support': 4},
#   '146': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '147': {'precision': 0.6,
#    'recall': 0.375,
#    'f1-score': 0.4615384615384615,
#    'support': 8},
#   '148': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '149': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 9},
#   '150': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '151': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '152': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '153': {'precision': 0.17647058823529413,
#    'recall': 0.5,
#    'f1-score': 0.2608695652173913,
#    'support': 6},
#   '154': {'precision': 0.1111111111111111,
#    'recall': 0.3,
#    'f1-score': 0.16216216216216217,
#    'support': 10},
#   '155': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '156': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 9},
#   '157': {'precision': 1.0,
#    'recall': 0.16666666666666666,
#    'f1-score': 0.2857142857142857,
#    'support': 6},
#   '158': {'precision': 1.0,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.8,
#    'support': 3},
#   '159': {'precision': 0.42857142857142855,
#    'recall': 0.5,
#    'f1-score': 0.4615384615384615,
#    'support': 6},
#   '160': {'precision': 0.4,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.3636363636363636,
#    'support': 6},
#   '161': {'precision': 0.14285714285714285,
#    'recall': 0.06666666666666667,
#    'f1-score': 0.09090909090909091,
#    'support': 15},
#   '163': {'precision': 0.3333333333333333,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.3333333333333333,
#    'support': 6},
#   '164': {'precision': 0.2777777777777778,
#    'recall': 0.7142857142857143,
#    'f1-score': 0.4,
#    'support': 7},
#   '165': {'precision': 0.3333333333333333,
#    'recall': 0.18181818181818182,
#    'f1-score': 0.23529411764705885,
#    'support': 11},
#   '166': {'precision': 0.3076923076923077,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.42105263157894735,
#    'support': 6},
#   '167': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 11},
#   '168': {'precision': 0.6666666666666666,
#    'recall': 0.2857142857142857,
#    'f1-score': 0.4,
#    'support': 7},
#   '169': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '170': {'precision': 0.6470588235294118,
#    'recall': 0.9166666666666666,
#    'f1-score': 0.7586206896551724,
#    'support': 12},
#   '171': {'precision': 0.9,
#    'recall': 1.0,
#    'f1-score': 0.9473684210526316,
#    'support': 9},
#   '172': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '173': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '174': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '175': {'precision': 0.75,
#    'recall': 1.0,
#    'f1-score': 0.8571428571428571,
#    'support': 3},
#   '176': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 9},
#   '177': {'precision': 0.3333333333333333,
#    'recall': 1.0,
#    'f1-score': 0.5,
#    'support': 3},
#   '178': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '180': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '181': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#   '182': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '183': {'precision': 0.42857142857142855,
#    'recall': 0.75,
#    'f1-score': 0.5454545454545454,
#    'support': 12},
#   '184': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 10},
#   '185': {'precision': 0.5625,
#    'recall': 0.9,
#    'f1-score': 0.6923076923076923,
#    'support': 10},
#   '186': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 12},
#   '187': {'precision': 1.0,
#    'recall': 0.14285714285714285,
#    'f1-score': 0.25,
#    'support': 7},
#   '188': {'precision': 0.6111111111111112,
#    'recall': 1.0,
#    'f1-score': 0.7586206896551725,
#    'support': 11},
#   '189': {'precision': 0.25, 'recall': 0.375, 'f1-score': 0.3, 'support': 8},
#   '190': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '191': {'precision': 0.6666666666666666,
#    'recall': 0.46153846153846156,
#    'f1-score': 0.5454545454545455,
#    'support': 13},
#   '193': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '194': {'precision': 0.6666666666666666,
#    'recall': 1.0,
#    'f1-score': 0.8,
#    'support': 8},
#   '195': {'precision': 0.5,
#    'recall': 1.0,
#    'f1-score': 0.6666666666666666,
#    'support': 1},
#   '196': {'precision': 1.0,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.5,
#    'support': 6},
#   '197': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '198': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '199': {'precision': 0.6666666666666666,
#    'recall': 0.5,
#    'f1-score': 0.5714285714285715,
#    'support': 4},
#   '200': {'precision': 0.8333333333333334,
#    'recall': 1.0,
#    'f1-score': 0.9090909090909091,
#    'support': 5},
#   '201': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '202': {'precision': 0.6,
#    'recall': 0.75,
#    'f1-score': 0.6666666666666665,
#    'support': 4},
#   '203': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '204': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '206': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '207': {'precision': 1.0,
#    'recall': 0.16666666666666666,
#    'f1-score': 0.2857142857142857,
#    'support': 6},
#   '208': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '209': {'precision': 0.2,
#    'recall': 0.1,
#    'f1-score': 0.13333333333333333,
#    'support': 10},
#   '210': {'precision': 0.3333333333333333,
#    'recall': 0.2,
#    'f1-score': 0.25,
#    'support': 5},
#   '211': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '212': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '213': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '214': {'precision': 1.0, 'recall': 0.25, 'f1-score': 0.4, 'support': 4},
#   '215': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '216': {'precision': 0.2222222222222222,
#    'recall': 0.25,
#    'f1-score': 0.23529411764705882,
#    'support': 8},
#   '218': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '219': {'precision': 0.5,
#    'recall': 0.2857142857142857,
#    'f1-score': 0.36363636363636365,
#    'support': 7},
#   '221': {'precision': 0.3,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.3529411764705882,
#    'support': 7},
#   '222': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '225': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '226': {'precision': 0.5833333333333334,
#    'recall': 0.875,
#    'f1-score': 0.7000000000000001,
#    'support': 8},
#   '227': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#   '228': {'precision': 0.5,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.4,
#    'support': 3},
#   '229': {'precision': 0.75,
#    'recall': 1.0,
#    'f1-score': 0.8571428571428571,
#    'support': 3},
#   '230': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '231': {'precision': 0.8,
#    'recall': 1.0,
#    'f1-score': 0.888888888888889,
#    'support': 4},
#   '232': {'precision': 0.7142857142857143,
#    'recall': 1.0,
#    'f1-score': 0.8333333333333333,
#    'support': 5},
#   '233': {'precision': 1.0,
#    'recall': 0.8571428571428571,
#    'f1-score': 0.923076923076923,
#    'support': 7},
#   '234': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '235': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '236': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '238': {'precision': 0.6,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.42857142857142855,
#    'support': 9},
#   '239': {'precision': 1.0,
#    'recall': 0.75,
#    'f1-score': 0.8571428571428571,
#    'support': 4},
#   '240': {'precision': 0.5,
#    'recall': 0.8571428571428571,
#    'f1-score': 0.631578947368421,
#    'support': 7},
#   '241': {'precision': 1.0,
#    'recall': 0.5,
#    'f1-score': 0.6666666666666666,
#    'support': 4},
#   '242': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '243': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7},
#   '244': {'precision': 0.45454545454545453,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.5882352941176471,
#    'support': 6},
#   '245': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '246': {'precision': 0.5,
#    'recall': 0.2857142857142857,
#    'f1-score': 0.36363636363636365,
#    'support': 7},
#   '248': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '249': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '250': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 6},
#   '251': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '252': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '253': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 8},
#   '254': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '255': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '256': {'precision': 0.5,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.4,
#    'support': 3},
#   '257': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '258': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '260': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '261': {'precision': 0.8,
#    'recall': 0.8,
#    'f1-score': 0.8000000000000002,
#    'support': 5},
#   '262': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7},
#   '263': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '264': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '266': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '267': {'precision': 0.5,
#    'recall': 0.7272727272727273,
#    'f1-score': 0.5925925925925926,
#    'support': 11},
#   '268': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#   'accuracy': 0.5674518201284796,
#   'macro avg': {'precision': 0.4760515217016808,
#    'recall': 0.48201185066972035,
#    'f1-score': 0.4532416865026616,
#    'support': 1868},
#   'weighted avg': {'precision': 0.5484267819497389,
#    'recall': 0.5674518201284796,
#    'f1-score': 0.530998519271083,
#    'support': 1868}})

# %% [markdown]
# # Using best parameters for 109 users

# %%
# Random subset of users
unique_users = trajectories_df['user_id'].unique()
random.seed(42)
selected_users = random.sample(list(unique_users), 109)

filtered_df = trajectories_df[trajectories_df['user_id'].isin(selected_users)].reset_index(drop=True)

# Label encode user_id
label_encoder = LabelEncoder()
filtered_df["label"] = label_encoder.fit_transform(filtered_df["user_id"])
num_users = len(label_encoder.classes_)
print(f"Number of selected users: {num_users}")

train_df, val_df = train_test_split(filtered_df, test_size=0.2, random_state=42)
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
# Out:
# Number of selected users: 109

# %%
# Best Hyperparams
best_dropout = 0.0
best_lr = 3e-5
best_batch_size = 16
best_max_length = 128

train_dataset = SpatioTemporalFoursquareDataset(train_df, tokenizer, max_length=best_max_length)
val_dataset = SpatioTemporalFoursquareDataset(val_df, tokenizer, max_length=best_max_length)

train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)

# %%
class TrajectoryDistilBERT(nn.Module):
    def __init__(self, num_users, dropout_rate=0.1):
        super(TrajectoryDistilBERT, self).__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.bert.config.dim, num_users)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        # DistilBERT's last_hidden_state: (batch_size, seq_len, hidden_size)
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# %%
# Build the model 
model = TrajectoryDistilBERT(num_users, dropout_rate=best_dropout)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# TrajectoryDistilBERT(
#   (bert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (classifier): Linear(in_features=768, out_features=109, bias=True)
# )

# %%
optimizer = AdamW(model.parameters(), lr=best_lr)
loss_fn = nn.CrossEntropyLoss()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
epochs = 10  
train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1:
#   Train Loss: 2.1907 | ACC@1: 0.4137, ACC@5: 0.8037
#   Val   Loss: 2.2956   | ACC@1: 0.3935, ACC@5: 0.7704
#   Val Macro F1: 0.1942, Weighted F1: 0.2877
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 2:
#   Train Loss: 1.2377 | ACC@1: 0.6297, ACC@5: 0.9440
#   Val   Loss: 1.4041   | ACC@1: 0.5878, ACC@5: 0.9166
#   Val Macro F1: 0.4457, Weighted F1: 0.5204
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 3:
#   Train Loss: 1.0197 | ACC@1: 0.6601, ACC@5: 0.9639
#   Val   Loss: 1.1884   | ACC@1: 0.6546, ACC@5: 0.9372
#   Val Macro F1: 0.5251, Weighted F1: 0.6012
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 4:
#   Train Loss: 0.9246 | ACC@1: 0.6726, ACC@5: 0.9723
#   Val   Loss: 1.1066   | ACC@1: 0.6330, ACC@5: 0.9441
#   Val Macro F1: 0.5288, Weighted F1: 0.5890
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 5:
#   Train Loss: 0.8519 | ACC@1: 0.6886, ACC@5: 0.9774
#   Val   Loss: 1.0433   | ACC@1: 0.6526, ACC@5: 0.9509
#   Val Macro F1: 0.5292, Weighted F1: 0.6005
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 6:
#   Train Loss: 0.7699 | ACC@1: 0.7249, ACC@5: 0.9843
#   Val   Loss: 0.9778   | ACC@1: 0.6860, ACC@5: 0.9529
#   Val Macro F1: 0.5814, Weighted F1: 0.6481
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 7:
#   Train Loss: 0.7103 | ACC@1: 0.7502, ACC@5: 0.9855
#   Val   Loss: 0.9747   | ACC@1: 0.6771, ACC@5: 0.9539
#   Val Macro F1: 0.5741, Weighted F1: 0.6413
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 8:
#   Train Loss: 0.6540 | ACC@1: 0.7585, ACC@5: 0.9885
#   Val   Loss: 0.9364   | ACC@1: 0.7046, ACC@5: 0.9539
#   Val Macro F1: 0.6147, Weighted F1: 0.6826
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 9:
#   Train Loss: 0.6013 | ACC@1: 0.7948, ACC@5: 0.9902
#   Val   Loss: 0.9178   | ACC@1: 0.7184, ACC@5: 0.9539
#   Val Macro F1: 0.6223, Weighted F1: 0.7011
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 10:
#   Train Loss: 0.5591 | ACC@1: 0.8025, ACC@5: 0.9897
#   Val   Loss: 0.9191   | ACC@1: 0.6977, ACC@5: 0.9549
#   Val Macro F1: 0.6139, Weighted F1: 0.6836
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # WITH TEST SET

# %%
# Random subset of users
unique_users = trajectories_df['user_id'].unique()
random.seed(42)
selected_users = random.sample(list(unique_users), 109)

filtered_df = trajectories_df[trajectories_df['user_id'].isin(selected_users)].reset_index(drop=True)

# Label encode user_id
label_encoder = LabelEncoder()
filtered_df["label"] = label_encoder.fit_transform(filtered_df["user_id"])
num_users = len(label_encoder.classes_)
print(f"Number of selected users: {num_users}")

# Split data into training, validation, and test sets
train_df, temp_df = train_test_split(filtered_df, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# Best Hyperparams
best_dropout = 0.0
best_lr = 3e-5
best_batch_size = 16
best_max_length = 128

# Create datasets
train_dataset = SpatioTemporalFoursquareDataset(train_df, tokenizer, max_length=best_max_length)
val_dataset = SpatioTemporalFoursquareDataset(val_df, tokenizer, max_length=best_max_length)
test_dataset = SpatioTemporalFoursquareDataset(test_df, tokenizer, max_length=best_max_length)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=best_batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=best_batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size, shuffle=False)

# Define model
class TrajectoryDistilBERT(nn.Module):
    def __init__(self, num_users, dropout_rate=0.1):
        super(TrajectoryDistilBERT, self).__init__()
        self.bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(self.bert.config.dim, num_users)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# Build the model 
model = TrajectoryDistilBERT(num_users, dropout_rate=best_dropout)
model.to(device)

# Optimizer and loss
optimizer = AdamW(model.parameters(), lr=best_lr)
loss_fn = nn.CrossEntropyLoss()

# Training function
epochs = 10  
train_model(model, train_loader, val_loader, device, loss_fn, optimizer, epochs=epochs)

# Evaluation function for test set
from sklearn.metrics import classification_report

def evaluate_test_set(model, loader, device, loss_fn):
    model.eval()
    total_loss = 0.0
    all_preds, all_labels = [], []
    acc_metrics = {"ACC@1": 0, "ACC@5": 0}
    total_samples = 0

    with torch.no_grad():
        for batch in loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            batch_size = labels.size(0)
            total_loss += loss.item() * batch_size

            batch_metrics = compute_metrics(outputs, labels)
            acc_metrics["ACC@1"] += batch_metrics["ACC@1"] * batch_size
            acc_metrics["ACC@5"] += batch_metrics["ACC@5"] * batch_size

            all_preds.extend(batch_metrics["top1_preds"].cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_samples += batch_size

    # Compute averages
    avg_loss = total_loss / total_samples
    acc_metrics["ACC@1"] /= total_samples
    acc_metrics["ACC@5"] /= total_samples

    # Generate classification report
    cls_metrics = classification_report(all_labels, all_preds, output_dict=True)
    
    print(f"Test Loss: {avg_loss:.4f}")
    print(f"ACC@1: {acc_metrics['ACC@1']:.4f}")
    print(f"ACC@5: {acc_metrics['ACC@5']:.4f}")
    
    return avg_loss, acc_metrics, cls_metrics

# Evaluate the test set
print("Evaluating the model on the test set...")
evaluate_test_set(model, test_loader, device, loss_fn)
# Out:
# Number of selected users: 109
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1:
#   Train Loss: 2.2531 | ACC@1: 0.4306, ACC@5: 0.8154
#   Val   Loss: 2.3219   | ACC@1: 0.4110, ACC@5: 0.7880
#   Val Macro F1: 0.2265, Weighted F1: 0.3142
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 2:
#   Train Loss: 1.3825 | ACC@1: 0.5921, ACC@5: 0.9164
#   Val   Loss: 1.4507   | ACC@1: 0.5864, ACC@5: 0.9018
#   Val Macro F1: 0.4384, Weighted F1: 0.5207
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 3:
#   Train Loss: 1.1510 | ACC@1: 0.6306, ACC@5: 0.9285
#   Val   Loss: 1.2437   | ACC@1: 0.6060, ACC@5: 0.9175
#   Val Macro F1: 0.4976, Weighted F1: 0.5635
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 4:
#   Train Loss: 1.0056 | ACC@1: 0.6617, ACC@5: 0.9621
#   Val   Loss: 1.0973   | ACC@1: 0.6636, ACC@5: 0.9385
#   Val Macro F1: 0.5310, Weighted F1: 0.6115
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 5:
#   Train Loss: 0.8966 | ACC@1: 0.6881, ACC@5: 0.9734
#   Val   Loss: 1.0160   | ACC@1: 0.6584, ACC@5: 0.9516
#   Val Macro F1: 0.5597, Weighted F1: 0.6290
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 6:
#   Train Loss: 0.8631 | ACC@1: 0.6996, ACC@5: 0.9787
#   Val   Loss: 1.0122   | ACC@1: 0.6780, ACC@5: 0.9490
#   Val Macro F1: 0.5923, Weighted F1: 0.6500
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 7:
#   Train Loss: 0.7934 | ACC@1: 0.7254, ACC@5: 0.9787
#   Val   Loss: 0.9673   | ACC@1: 0.6911, ACC@5: 0.9476
#   Val Macro F1: 0.6143, Weighted F1: 0.6757
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 8:
#   Train Loss: 0.7427 | ACC@1: 0.7374, ACC@5: 0.9846
#   Val   Loss: 0.9330   | ACC@1: 0.6911, ACC@5: 0.9529
#   Val Macro F1: 0.6123, Weighted F1: 0.6710
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 9:
#   Train Loss: 0.6590 | ACC@1: 0.7700, ACC@5: 0.9877
#   Val   Loss: 0.8973   | ACC@1: 0.7160, ACC@5: 0.9516
#   Val Macro F1: 0.6404, Weighted F1: 0.7016
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 10:
#   Train Loss: 0.6056 | ACC@1: 0.7829, ACC@5: 0.9882
#   Val   Loss: 0.8876   | ACC@1: 0.6898, ACC@5: 0.9568
#   Val Macro F1: 0.6105, Weighted F1: 0.6772
# Evaluating the model on the test set...
# Test Loss: 0.8883
# ACC@1: 0.7111
# ACC@5: 0.9634
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.8882830199073343,
#  {'ACC@1': 0.7111111111111111, 'ACC@5': 0.9633986928104575},
#  {'0': {'precision': 0.9285714285714286,
#    'recall': 1.0,
#    'f1-score': 0.962962962962963,
#    'support': 13},
#   '1': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#   '2': {'precision': 0.75,
#    'recall': 0.8181818181818182,
#    'f1-score': 0.7826086956521738,
#    'support': 33},
#   '3': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '4': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '5': {'precision': 0.9444444444444444,
#    'recall': 1.0,
#    'f1-score': 0.9714285714285714,
#    'support': 17},
#   '6': {'precision': 0.7,
#    'recall': 0.7777777777777778,
#    'f1-score': 0.7368421052631577,
#    'support': 9},
#   '7': {'precision': 0.5769230769230769,
#    'recall': 0.8823529411764706,
#    'f1-score': 0.6976744186046512,
#    'support': 17},
#   '8': {'precision': 0.9545454545454546,
#    'recall': 1.0,
#    'f1-score': 0.9767441860465117,
#    'support': 21},
#   '10': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#   '11': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '12': {'precision': 0.8571428571428571,
#    'recall': 0.9230769230769231,
#    'f1-score': 0.888888888888889,
#    'support': 13},
#   '14': {'precision': 0.5384615384615384,
#    'recall': 0.875,
#    'f1-score': 0.6666666666666667,
#    'support': 8},
#   '15': {'precision': 0.7,
#    'recall': 0.875,
#    'f1-score': 0.7777777777777777,
#    'support': 8},
#   '16': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 15},
#   '17': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#   '18': {'precision': 0.5,
#    'recall': 0.7142857142857143,
#    'f1-score': 0.588235294117647,
#    'support': 14},
#   '19': {'precision': 0.5,
#    'recall': 1.0,
#    'f1-score': 0.6666666666666666,
#    'support': 1},
#   '20': {'precision': 0.8,
#    'recall': 1.0,
#    'f1-score': 0.888888888888889,
#    'support': 8},
#   '21': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   '22': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 16},
#   '23': {'precision': 0.55,
#    'recall': 0.6470588235294118,
#    'f1-score': 0.5945945945945946,
#    'support': 17},
#   '24': {'precision': 1.0,
#    'recall': 0.9444444444444444,
#    'f1-score': 0.9714285714285714,
#    'support': 18},
#   '25': {'precision': 0.5,
#    'recall': 1.0,
#    'f1-score': 0.6666666666666666,
#    'support': 1},
#   '26': {'precision': 0.6666666666666666,
#    'recall': 1.0,
#    'f1-score': 0.8,
#    'support': 4},
#   '27': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 13},
#   '28': {'precision': 0.8,
#    'recall': 0.8,
#    'f1-score': 0.8000000000000002,
#    'support': 10},
#   '29': {'precision': 1.0,
#    'recall': 0.875,
#    'f1-score': 0.9333333333333333,
#    'support': 16},
#   '30': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 3},
#   '31': {'precision': 0.875,
#    'recall': 0.7,
#    'f1-score': 0.7777777777777777,
#    'support': 10},
#   '32': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '33': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '35': {'precision': 0.5555555555555556,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.6666666666666667,
#    'support': 6},
#   '36': {'precision': 1.0,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.8,
#    'support': 12},
#   '37': {'precision': 0.8333333333333334,
#    'recall': 1.0,
#    'f1-score': 0.9090909090909091,
#    'support': 5},
#   '38': {'precision': 0.8888888888888888,
#    'recall': 1.0,
#    'f1-score': 0.9411764705882353,
#    'support': 16},
#   '39': {'precision': 0.8,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.7272727272727272,
#    'support': 12},
#   '41': {'precision': 1.0,
#    'recall': 0.9090909090909091,
#    'f1-score': 0.9523809523809523,
#    'support': 11},
#   '43': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 3},
#   '44': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#   '45': {'precision': 0.4444444444444444,
#    'recall': 0.3076923076923077,
#    'f1-score': 0.3636363636363637,
#    'support': 13},
#   '46': {'precision': 1.0,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.9090909090909091,
#    'support': 6},
#   '47': {'precision': 1.0,
#    'recall': 0.9090909090909091,
#    'f1-score': 0.9523809523809523,
#    'support': 11},
#   '48': {'precision': 0.5,
#    'recall': 0.375,
#    'f1-score': 0.42857142857142855,
#    'support': 8},
#   '49': {'precision': 0.3333333333333333,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.375,
#    'support': 7},
#   '50': {'precision': 0.4444444444444444,
#    'recall': 0.8,
#    'f1-score': 0.5714285714285714,
#    'support': 5},
#   '51': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 2},
#   '52': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '53': {'precision': 0.3333333333333333,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.4444444444444444,
#    'support': 3},
#   '55': {'precision': 0.6666666666666666,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.4444444444444444,
#    'support': 6},
#   '56': {'precision': 0.45454545454545453,
#    'recall': 0.8333333333333334,
#    'f1-score': 0.5882352941176471,
#    'support': 6},
#   '57': {'precision': 0.3333333333333333,
#    'recall': 0.7142857142857143,
#    'f1-score': 0.4545454545454545,
#    'support': 7},
#   '58': {'precision': 0.75,
#    'recall': 1.0,
#    'f1-score': 0.8571428571428571,
#    'support': 3},
#   '59': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 11},
#   '60': {'precision': 0.25,
#    'recall': 0.5,
#    'f1-score': 0.3333333333333333,
#    'support': 2},
#   '61': {'precision': 0.75,
#    'recall': 0.9,
#    'f1-score': 0.8181818181818182,
#    'support': 10},
#   '62': {'precision': 0.4,
#    'recall': 0.2,
#    'f1-score': 0.26666666666666666,
#    'support': 10},
#   '63': {'precision': 0.7777777777777778,
#    'recall': 0.7777777777777778,
#    'f1-score': 0.7777777777777778,
#    'support': 9},
#   '64': {'precision': 0.6666666666666666,
#    'recall': 1.0,
#    'f1-score': 0.8,
#    'support': 4},
#   '65': {'precision': 0.7777777777777778,
#    'recall': 0.5833333333333334,
#    'f1-score': 0.6666666666666666,
#    'support': 12},
#   '67': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 12},
#   '68': {'precision': 0.6,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.631578947368421,
#    'support': 9},
#   '69': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 6},
#   '70': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 7},
#   '71': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#   '72': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 7},
#   '73': {'precision': 0.5833333333333334,
#    'recall': 0.4666666666666667,
#    'f1-score': 0.5185185185185186,
#    'support': 15},
#   '74': {'precision': 0.875,
#    'recall': 1.0,
#    'f1-score': 0.9333333333333333,
#    'support': 7},
#   '75': {'precision': 0.8461538461538461,
#    'recall': 0.7857142857142857,
#    'f1-score': 0.8148148148148148,
#    'support': 14},
#   '76': {'precision': 1.0,
#    'recall': 0.4,
#    'f1-score': 0.5714285714285715,
#    'support': 5},
#   '77': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '78': {'precision': 0.9,
#    'recall': 1.0,
#    'f1-score': 0.9473684210526316,
#    'support': 9},
#   '80': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '81': {'precision': 0.8,
#    'recall': 0.4444444444444444,
#    'f1-score': 0.5714285714285714,
#    'support': 9},
#   '82': {'precision': 0.25,
#    'recall': 0.2,
#    'f1-score': 0.22222222222222224,
#    'support': 5},
#   '83': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 1},
#   '84': {'precision': 1.0,
#    'recall': 0.875,
#    'f1-score': 0.9333333333333333,
#    'support': 8},
#   '85': {'precision': 0.8571428571428571,
#    'recall': 0.8571428571428571,
#    'f1-score': 0.8571428571428571,
#    'support': 7},
#   '86': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '87': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '88': {'precision': 0.2,
#    'recall': 0.45454545454545453,
#    'f1-score': 0.2777777777777778,
#    'support': 11},
#   '89': {'precision': 0.3333333333333333,
#    'recall': 0.5,
#    'f1-score': 0.4,
#    'support': 6},
#   '90': {'precision': 0.8571428571428571,
#    'recall': 0.75,
#    'f1-score': 0.7999999999999999,
#    'support': 8},
#   '91': {'precision': 0.3333333333333333,
#    'recall': 0.5,
#    'f1-score': 0.4,
#    'support': 4},
#   '92': {'precision': 0.8,
#    'recall': 0.4,
#    'f1-score': 0.5333333333333333,
#    'support': 10},
#   '93': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 6},
#   '94': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 0},
#   '96': {'precision': 0.875, 'recall': 0.875, 'f1-score': 0.875, 'support': 8},
#   '97': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 8},
#   '98': {'precision': 0.75,
#    'recall': 0.42857142857142855,
#    'f1-score': 0.5454545454545454,
#    'support': 7},
#   '99': {'precision': 0.5, 'recall': 0.5, 'f1-score': 0.5, 'support': 2},
#   '100': {'precision': 0.25, 'recall': 1.0, 'f1-score': 0.4, 'support': 5},
#   '101': {'precision': 0.75, 'recall': 0.75, 'f1-score': 0.75, 'support': 4},
#   '102': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 1},
#   '103': {'precision': 0.16666666666666666,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.26666666666666666,
#    'support': 3},
#   '104': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 2},
#   '105': {'precision': 1.0,
#    'recall': 0.4,
#    'f1-score': 0.5714285714285715,
#    'support': 5},
#   '106': {'precision': 1.0,
#    'recall': 0.3333333333333333,
#    'f1-score': 0.5,
#    'support': 3},
#   '107': {'precision': 0.6666666666666666,
#    'recall': 0.6666666666666666,
#    'f1-score': 0.6666666666666666,
#    'support': 9},
#   '108': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 4},
#   'accuracy': 0.7111111111111111,
#   'macro avg': {'precision': 0.6229562937062937,
#    'recall': 0.6499077262606674,
#    'f1-score': 0.6168481792716516,
#    'support': 765},
#   'weighted avg': {'precision': 0.6997060637256715,
#    'recall': 0.7111111111111111,
#    'f1-score': 0.6907237343392709,
#    'support': 765}})
